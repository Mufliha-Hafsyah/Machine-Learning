# %% [markdown]
# <a href="https://colab.research.google.com/github/Mufliha-Hafsyah/Machine-Learning/blob/main/TG1_244107020147_Mufliha_Hafsyah_Shahieza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRAKTIKUM PEMBELAJARAN MESIN
#
# **Nama**  : Mufliha Hafsyah Shahieza <br>
# **NIM**   : 244107020147 <br>
# **Kelas** : TI-3G
#
# ---
#
# ## JS01 - Pengenalan Pembelajaran Mesin

# %% [markdown]
# ## **Tugas Praktikum 1**
#
# ### **Bagian 1**
# Lakukan instalasi library berikut pada notebook. Jelaskan kegunakan masing-masing library tersebut.
#
# 1. **PyPREP**<br>
# PyPREP adalah library Python yang mengimplementasikan "PREP pipeline", yaitu standar preprocessing untuk data sinyal EEG (electroencephalogram). Fungsinya antara lain mendeteksi dan memperbaiki channel elektroda yang bermasalah (noisy/rusak), melakukan referencing ulang sinyal, dan menghilangkan gangguan listrik (line noise) sebelum data EEG dianalisis lebih lanjut.

# %%
# !pip install pyprep
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 30.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.3.1 which is incompatible.
# ...

# %% [markdown]
# 2. **SciPy**<br>
# SciPy adalah library komputasi ilmiah untuk Python yang dibangun di atas NumPy. Library ini menyediakan berbagai fungsi matematika lanjutan seperti aljabar linear, integrasi, optimasi, statistik, dan pengolahan sinyal. Dalam machine learning, SciPy sering dipakai sebagai fondasi untuk operasi numerik yang dibutuhkan library lain seperti scikit-learn.

# %%
# !pip install scipy

# %% [markdown]
# 3. **Wandb (Weights & Biases)**<br>
# Wandb adalah tool untuk melacak (tracking) dan mengelola eksperimen machine learning. Dengan Wandb, kita bisa mencatat metrik training (seperti loss dan akurasi) secara otomatis, membandingkan performa antar model atau antar percobaan, serta memvisualisasikan hasilnya secara online melalui dashboard, sehingga memudahkan proses eksperimen dan kolaborasi tim.

# %%
# !pip install wandb

# %% [markdown]
# 4. **pyECG**<br>
# pyECG adalah library untuk memproses dan menganalisis sinyal ECG (elektrokardiogram), yaitu rekaman aktivitas listrik jantung. Library ini biasanya digunakan untuk mendeteksi puncak gelombang R, menghitung detak jantung (heart rate), dan melakukan analisis lain terkait sinyal jantung dalam konteks pengolahan data medis/biosignal.

# %%
# !pip install pyecg
# Out:
# ...
#   Using cached pyECG-0.0.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# ...
#   Using cached ishneholterlib-2017.4.11.tar.gz (7.0 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached wfdb-2.2.1.tar.gz (94 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pytest_cov-7.1.0-py3-none-any.whl.metadata (32 kB)
# ...
#   Using cached pycrc-0.11.0-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached nose-1.3.7-py3-none-any.whl.metadata (1.7 kB)
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.5/257.5 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 12.2 MB/s eta 0:00:00
# ...
#   Created wheel for ishneholterlib: filename=ishneholterlib-2017.4.11-py3-none-any.whl size=7504 sha256=f4e187c23f1bd35bf941835a1404a8ac6d5a206fe89b94b2c9be548f2d071005
#   Stored in directory: /root/.cache/pip/wheels/60/50/d1/db6b1d062f56ed24c391a2d51126d1341cc51381bed8a2de61
# ...
